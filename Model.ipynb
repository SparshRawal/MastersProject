# %%
import tensorflow as tf;
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2023-06-29 19:46:56.874660: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-29 19:46:57.426438: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-29 19:46:57.525060: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-06-29 19:46:57.525124: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-06-29 19:46:59.428686: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-06-29 19:46:59.428824: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-06-29 19:46:59.428836: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# []
# 2023-06-29 19:47:01.531698: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-06-29 19:47:01.531934: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-06-29 19:47:01.531962: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (dulcimer.inf.ed.ac.uk): /proc/driver/nvidia/version does not exist

# %%
utt2lang = open('master/dev/utt2lang')
d1 = {}
for line in utt2lang.readlines():
    ls = line.split(' ')
    d1[ls[0]] = ls[1].replace("\n",'')
print(list(d1.keys())[:100])
# Out:
# ['10000433182905965494.wav', '10001989386776303806.wav', '10002654614769396659.wav', '10002918185140135837.wav', '10003052334395007599.wav', '10003175936942512650.wav', '10003386135529782184.wav', '10003907204622388362.wav', '10005074780302165342.wav', '10005228519380753710.wav', '1000560306296507844.wav', '10005687533826592442.wav', '10006368250553379654.wav', '10006407814778220908.wav', '10006717964432115182.wav', '10007075289580383602.wav', '10007880321414199012.wav', '1000847601644945595.wav', '10008952308856727947.wav', '10009621509886822059.wav', '10010138729160973689.wav', '10010857400500299298.wav', '10011106960538242224.wav', '10011453964663514159.wav', '10011559019525194153.wav', '1001164909909643102.wav', '10012360550181770926.wav', '10012421007954814049.wav', '10012746004804583610.wav', '10013199422658976283.wav', '10013545268133211816.wav', '10013862322662606214.wav', '10015838705897580692.wav', '10016733824831284541.wav', '10017444110191735282.wav', '10017639081645832204.wav', '10018492969996036091.wav', '10019700427401071550.wav', '10020154943353133064.wav', '10020283897811844164.wav', '10020394196171973418.wav', '10020766392768580989.wav', '10021311324523185658.wav', '10021553664869429171.wav', '10023071140206119545.wav', '10023268074612471948.wav', '10023639670089300637.wav', '10023988885249671485.wav', '10024237679822536626.wav', '10025505890476523442.wav', '10025573610249428400.wav', '10025796746930914758.wav', '10026307554055809059.wav', '10026472766083365099.wav', '10027356231711165633.wav', '10027710469591428283.wav', '10028896103651079035.wav', '10029697631083772600.wav', '10030969252796176788.wav', '10031156686197511771.wav', '10031412691154736538.wav', '10031551826755212472.wav', '10032516365537853635.wav', '10032534896609126950.wav', '10032682177110039956.wav', '10033329815200977556.wav', '10034449541122537267.wav', '10034672635517696124.wav', '1003567887281500142.wav', '10035998729701048400.wav', '10036370007862814854.wav', '10036701932997330991.wav', '10037088208308542843.wav', '10037731174859378340.wav', '10037968623013233667.wav', '10038748858375733352.wav', '10039106476701534373.wav', '10039278052863422447.wav', '10039386502091710584.wav', '10039824435567831360.wav', '10040723975064123890.wav', '10040732815262830552.wav', '10040842285215808423.wav', '1004101932027003160.wav', '10042024963401505302.wav', '10042203520901241191.wav', '10042618008895891646.wav', '10043827527204102024.wav', '10044952078382860108.wav', '10045358569493902894.wav', '10045457533521947678.wav', '10045768324029099382.wav', '10046564361812626104.wav', '10046662700639273789.wav', '10047391616305510130.wav', '10048936086716497230.wav', '10049006222377318397.wav', '10049193449524811295.wav', '100493038325060176.wav', '10049974925527451150.wav']

# %%
phones = open('master/dev/phones.txt')
d2 = {}
for line in phones.readlines():
    ls = line.split(' ')
    d2[ls[0]] = ' '.join(ls[1:len(ls)-1])
phones = open('master/dev/phones.txt')
d3 = {}
for line in phones.readlines():
    ls = line.split(' ')
    d3[ls[0]] = ls[1:len(ls)-1]
print(d3['10000433182905965494.wav'])
# Out:
# ['sil', 'r', 'O', 'i', 'v', 'e', 'N\\', 'x', 'j', 'e', 'b', 'e', 'd', 'a', 'l', 'sil', 'a', 'sil', 'O', 'l', 'm', 'p', 'a', 'i', 'D', 'i', 'v', 'o', 'd', 'i', 'n', 'O', 'v', 'i', 'O', 'sil', '@', 'n', '@', 'd', 'i', 'x', 'r', 'i', 'v', 'sil', 'k', 'A', 'n', 't', 'm', 'E', 't', '@`', 'sil', 'a', 'd', 'd', 'a', 'i', 'k', 'A', 'n', 't', 'sil', 't', 'r', 'i', 'd', 'E', 'g', 'm', 'E', 't', '@`', 'sil', 'a', 'k', 'm', 'aU', 'n', 't', 'a', 'i', 'r\\', 'A', 's', 'g', '@', 'v', 'n', 'E', 'w', 'E', 'd', 'E', 'sil', 'm', 'a', 'i', 'sil', 'g', 'a', 'm', 'a', 'n', 'w', 'A', 'd', 'sil', 'O', 'n', 'd', 'O', 'x', 'r', 'u', '1', 'D', 'e', 'i', 'b', 'r', 'O', 'b', 'l', 'E', 'm', 'a', 'i', 'm', 'a', 'i', '{', 'm', 'h', 'a', 'i', 'a', 'i', 'T', 'sil', 'a', 'm', 'a', 'i', 'f', 'i', 't', 'r', 'j', 'sil']

# %%
print(d2['10000433182905965494.wav'])
# Out:
# sil r O i v e N\ x j e b e d a l sil a sil O l m p a i D i v o d i n O v i O sil @ n @ d i x r i v sil k A n t m E t @` sil a d d a i k A n t sil t r i d E g m E t @` sil a k m aU n t a i r\ A s g @ v n E w E d E sil m a i sil g a m a n w A d sil O n d O x r u 1 D e i b r O b l E m a i m a i { m h a i a i T sil a m a i f i t r j sil

# %%
print(len(d1))
# Out:
# 34452

# %%
print(len(d2))
# Out:
# 34452

# %%
from collections import defaultdict
merged = defaultdict(list)

for d in (d1, d2):
    for key, value in d.items():
        merged[key].append(value)

# %%
print((merged['10000433182905965494.wav']))
# Out:
# ['cy_gb', 'sil r O i v e N\\ x j e b e d a l sil a sil O l m p a i D i v o d i n O v i O sil @ n @ d i x r i v sil k A n t m E t @` sil a d d a i k A n t sil t r i d E g m E t @` sil a k m aU n t a i r\\ A s g @ v n E w E d E sil m a i sil g a m a n w A d sil O n d O x r u 1 D e i b r O b l E m a i m a i { m h a i a i T sil a m a i f i t r j sil']

# %%
import json
js = []
for k,v in merged.items():
    writeTofile = {}
    writeTofile['id'] = k
    writeTofile['language'] = v[0]
    writeTofile['phoneSequence'] = v[1]
    js.append(writeTofile)

# %% [markdown]
# ## Write Data to Json

# %%
with open('master/dev/data.json', 'a') as f:
    json.dump(js, f)

# %% [markdown]
# ## Read Json

# %%
with open("master/train/data.json", "r") as read_file:
    trainingData = json.load(read_file)
print(len(trainingData))
# Out:
# 271798

# %%
langs = []
phone_seqs = []
for dataPoint in trainingData:
    langs.append(dataPoint['language'])
    phone_seqs.append(dataPoint['phoneSequence'])

# %%
print(len(langs))
print(len(phone_seqs))
X_train = phone_seqs
y_train = langs
# Out:
# 271798
# 271798

# %%
with open("master/dev/data.json", "r") as read_file:
    devData = json.load(read_file)
print(len(devData))

devLangs = []
devPhone_seqs = []

for dataPoint in devData:
    devLangs.append(dataPoint['language'])
    devPhone_seqs.append(dataPoint['phoneSequence'])

print(len(devLangs))
print(len(devPhone_seqs))
X_dev = devPhone_seqs
y_dev = devLangs
# Out:
# 34452
# 34452
# 34452

# %%
print(X_train[0:10])
print(y_train[0:10],end = '\n')
# Out:
# ['sil a k a b a t u m ye o n a f u n z i w a ts_j i w O k i k u ts_j a n d a n i sil b a r u a p E sil n a k a p a t a sil m a t a l e o m e e N\\ g i s a n a sil j a m a l a z j i sil j a b u 4 e sil', 'sil d a l i sil v a s i s i d a sil n a n t a r a sil n i sil n i m a u r i g ye m a 4 e l i d a g a sil n i u sil x o s a s a m s k r u t i g E x O n d i k o n d i t d i 4 i sil m a t o n i m a sil k u t o m b a s o m s k o t i i n d a k e l a v u sil a b i a s a g l a n o sil k a l e d u k o n d i t d i 4 i sil', 'sil d E n z i a v o p i N\\ n a ye k o t f o m l o sil m o d a t i a t d i k a s a m s k a r a n a l e L e 4 i g a i sil', 'sil O S E b i E s E k sil i S_j m E r t E k k y l E m f e l E n i u k t O t O k o t sil k y s t 1 k O m a k k i v O n O d b o e s a r m O z a u m u r v i n d sil E S O b E l i 1 n d E k m O g v sil s a r m O z o s k o p O l O m i n d sil', 'sil b r o j b O g i n u l E x i n a j m a n ye p E t n a j s t sil a O ts_j E k u e s E d a tS 1 t a j b r o ye r a s t 1 sil', 'sil s u d j a ye r ye k a o b l e i k u sil d a e s k O r O n E j z b ye z\\ n u d a ts_j O t i ts_j u z a t v o r sil', 'sil v S 1 s t k O v s k a s u j E n a t O rZ a n v ts a w O S_j ts_j u O p i E rZ a n 1 ts_j E p w O k r v i s t E p t a k z g r u p E d r a p i E rZ n i k u v sil p O r u S a w S_j E v p O z 1 ts j i p i a n O v E j n a d v u x n O g a x sil i m i a w p O z O r 1 p O d O b n E d O v E l O t i r a p t O r a sil', 'sil s u f i l n i m a D a sil n o sil m a x a sil m a b e d a sil a b u d i s t e d a sil x a r k a s u dz_j i D e sil s k a sil n a v d u n a sil s k a x l a l E sil n a x a 4 i s t a l E sil x i r k a sil 1 h i t a sil f a r a x a l E sil', 'sil m u n a n a j n t i n s e b e n t i s e b e N\\ sil d o k t a d e m a d j e n v a G a p ye d z a k u G a D e 4 a sil e m a 4 a a i s k a n a sil i a i b o n a m u 4 j e s e sil i o j a b a k a tS i sil i n d o m i t e b o sil', 'sil v e s r i d o i n a ts j O n a l n a k u S a r k a s k a z w 1 z a z d r u z\\ i n i x d r z\\ a u sil m b i E j sil p r ye k i n i l a s E z o n u sil p o k l i ts n 1 k O S a r k o r s k E l i g i E z a r a d i z a d r S k u v u z_j i i z k O b i d d e b e t n a j s t sil']
# ['sw_ke', 'kn_in', 'te_in', 'hu_hu', 'hr_hr', 'sr_rs', 'pl_pl', 'so_so', 'sn_zw', 'sl_si']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
# X_train, X_test, y_train, y_test = train_test_split(phone_seqs, langs, test_size=0.2, random_state=42)

# Initialize the TF-IDF vectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,4))

# Fit and transform the training data
X_train_tfidf = vectorizer.fit_transform(X_train)

# Transform the testing data
X_test_tfidf = vectorizer.transform(X_dev)

# Initialize the logistic regression classifier
classifier = LogisticRegression(random_state=42, 
   verbose=1,max_iter=1000,n_jobs=8)

# Train the classifier
classifier.fit(X_train_tfidf, y_train)

# Predict the labels for the testing data
y_pred = classifier.predict(X_test_tfidf)

# Calculate accuracy
accuracy = accuracy_score(y_dev, y_pred)
print("Accuracy:", accuracy)
# Out:
# [Parallel(n_jobs=8)]: Using backend LokyBackend with 8 concurrent workers.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =      5979546     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.25706D+06    |proj g|=  1.73869D+03
#  This problem is unconstrained.
# At iterate   50    f=  9.30803D+05    |proj g|=  5.45294D+02
#
# At iterate  100    f=  9.15088D+05    |proj g|=  2.64132D+02
#
# At iterate  150    f=  9.13317D+05    |proj g|=  4.10905D+01
#
# At iterate  200    f=  9.13173D+05    |proj g|=  9.80421D+00
#
# At iterate  250    f=  9.13159D+05    |proj g|=  5.00227D+00
#
# At iterate  300    f=  9.13158D+05    |proj g|=  7.60024D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# *****    305    321      1     0     0   2.114D+00   9.132D+05
#   F =   913157.93250467349
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# [Parallel(n_jobs=8)]: Done   1 out of   1 | elapsed: 16.4min finished
# Accuracy: 0.15586903517938

# %%
langSet = []
for lang in y_train:
    if lang not in langSet:
        langSet.append(lang)
num_classes = len(langSet)
print(num_classes)
# Out:
# 102

# %%
import numpy as np
lang_to_index = {lang: index for index, lang in enumerate(langSet)}
def lang_to_one_hot(language):
    """
    Convert a phoneme to a one-hot encoded vector.
    """
    num_langs = len(langSet)
    one_hot = np.zeros(num_langs)
    one_hot[lang_to_index[language]] = 1
    return one_hot
y_train_one_hot = [lang_to_one_hot(lang) for lang in y_train]
y_dev_one_hot = [lang_to_one_hot(lang) for lang in y_dev]

# %%
print(len(y_dev_one_hot[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2719375/4142121368.py in <module>
# ----> 1 print(len(y_dev_one_hot[0]))
#
# NameError: name 'y_dev_one_hot' is not defined

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.feature_extraction.text import TfidfVectorizer

# Assuming you have preprocessed data in phone_sequences and y_train

# Create an instance of TfidfVectorizer
vectorizer = TfidfVectorizer()

# Convert phone sequences to TF-IDF features
X_train_tfidf = vectorizer.fit_transform(X_train)

# Convert the sparse TF-IDF matrix to a dense numpy array
X_train_tfidf = X_train_tfidf.toarray()

# Reshape the TF-IDF features to match the input shape of the RNN model
# X_train_rnn = np.reshape(X_train_tfidf, (X_train_tfidf.shape[0], 1, X_train_tfidf.shape[1]))

# Define the RNN model
model = keras.Sequential()
model.add(layers.SimpleRNN(units=64, input_shape=(1, X_train_tfidf.shape[1])))
model.add(layers.Dense(units=num_classes, activation='softmax'))


# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

y_train_one_hot = np.array(y_train_one_hot)
# y_train_rnn = y_train_one_hot.reshape(y_train_one_hot,(y_train_one_hot.shape[0],1,y_train_one_hot.shape[1]))
print(y_train_one_hot.shape)
print(X_train_tfidf.shape)
print(model.summary())
# Train the model
model.fit(X_train_tfidf, y_train_one_hot, batch_size=50, epochs=10, validation_split=0.2)

# Assuming you have preprocessed data in X_test and y_test

# Convert phone sequences in the test set to TF-IDF features
# X_test_tfidf = vectorizer.transform(X_test)
# X_test_tfidf = X_test_tfidf.toarray()

# Reshape the TF-IDF features for the test set
# X_test_rnn = np.reshape(X_test_tfidf, (X_test_tfidf.shape[0], 1, X_test_tfidf.shape[1]))

# Evaluate the model on the test data
# loss, accuracy = model.evaluate(X_test_rnn, y_dev_one_hot)
# print("Test Loss:", loss)
# print("Test Accuracy:", accuracy)
# Out:
# (271798, 102)
# (271798, 33)
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_18 (SimpleRNN)   (None, 64)                6272
#
#  dense_18 (Dense)            (None, 102)               6630
#
# =================================================================
# Total params: 12,902
# Trainable params: 12,902
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing import sequence
# fix random seed for reproducibility
# tf.random.set_seed(7)
# You need to load the IMDB dataset. You are constraining the dataset to the top 5,000 words. You will also split the dataset into train (50%) and test (50%) sets.

# load the dataset but only keep the top n words, zero the rest
top_words = 5000
(X_train_imdb, y_train_imdb), (X_test_imdb, y_test_imdb) = imdb.load_data(num_words=top_words)

# %%
# (X_train_imdb, y_train_imdb), (X_test_imdb, y_test_imdb) = imdb.load_data(num_words=top_words)
y_train_imdb.shape
# Out:
# (25000,)

# %%
import numpy as np
def phoneme_to_one_hot(phoneme):
    """
    Convert a phoneme to a one-hot encoded vector.
    """
    num_phonemes = len(phoneme_vocab)
    one_hot = np.zeros(num_phonemes)
    one_hot[phoneme_to_index[phoneme]] = 1
    return one_hot

# %%
import numpy as np
def lang_to_one_hot(phoneme):
    """
    Convert a phoneme to a one-hot encoded vector.
    """
    num_langs = len(langSet)
    one_hot = np.zeros(num_langs)
    one_hot[lang_to_index[phoneme]] = 1
    return one_hot

# %%
phones = {}
for ps in d3.values():
    for phone in ps:
        if phone not in phones:
            phones[phone] = 1
# print(phones)
tokenized_sequences = list(d3.values())
phonemes = set()
for sequence in tokenized_sequences:
    phonemes.update(sequence)

phoneme_vocab = list(phonemes)
# phoneme_vocab = list(phonemes)
# print(phoneme_vocab)
phoneme_to_index = {phoneme: index for index, phoneme in enumerate(phoneme_vocab)}
# # print(phoneme_to_index)
# numerical_sequences = [[phoneme_to_index[phoneme] for phoneme in seq] for seq in tokenized_sequences]
one_hot_phones_seq = [[phoneme_to_one_hot(phoneme) for phoneme in seq] for seq in tokenized_sequences]

# from tensorflow.keras.preprocessing.sequence import pad_sequences

# max_sequence_length = max(len(seq) for seq in numerical_sequences)

# padded_sequences = pad_sequences(numerical_sequences, maxlen=max_sequence_length, padding='post')

# %%
one_hot_phone_seq_np = np.array()
# for seq in one_hot_phones_seq:
#     print(np.a)
print(np.asarray(one_hot_phone_seq_np))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2141584/680404834.py in <module>
# ----> 1 one_hot_phone_seq_np = np.array()
#       2 # for seq in one_hot_phones_seq:
#       3 #     print(np.a)
#       4 print(np.asarray(one_hot_phone_seq_np))
#
# TypeError: array() missing required argument 'object' (pos 0)

# %%
langSet = []
for lang in langs:
    if lang not in langSet:
        langSet.append(lang)
lang_to_index = {lang: index for index, lang in enumerate(langSet)}
one_hot_lang = [lang_to_one_hot(lang) for lang in langs]
print(np.array(one_hot_lang).shape)
# Out:
# (7915, 3)

# %%
# max_sequence_length = max(len(seq) for seq in one_hot_phones_seq)
max_sequence_length = -1
for seq in one_hot_phones_seq:
    if(len(seq)>max_sequence_length):
        max_sequence_length=len(seq)
print(max_sequence_length)
# Out:
# 363

# %%
from tensorflow import keras
from tensorflow.keras import layers

# X_train, X_test, y_train, y_test = train_test_split(one_hot_phones_seq, one_hot_lang, test_size=0.2, random_state=42)

# Assuming you have preprocessed data in X_train and y_train
num_phonemes = len(phoneme_vocab)
array = np.array(one_hot_lang)
print(array.shape)
# Define the RNN model
# model = keras.Sequential()
# model.add(layers.SimpleRNN(units=64, input_shape=(max_sequence_length, num_phonemes)))
# model.add(layers.Dense(units=len(langSet), activation='softmax'))

# # Compile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
# model.fit(X_train, y_train, batch_size=10, epochs=10, validation_split=0.2)

# Assuming you have preprocessed data in X_test and y_test

# Evaluate the model on test data
# loss, accuracy = model.evaluate(X_test, y_test)
# print("Test Loss:", loss)
# print("Test Accuracy:", accuracy)
# Out:
# (7915, 3)

# %%
from tensorflow import keras
from tensorflow.keras import layers

# Assuming you have preprocessed data in X_train and y_train

# Define the RNN model
model = keras.Sequential()
model.add(layers.Embedding(input_dim=len(phoneme_vocab), output_dim=len(phoneme_vocab), input_length=max_sequence_length))
model.add(layers.SimpleRNN(units=64))
model.add(layers.Dense(units=len(langs), activation='softmax'))

# X_train, X_test, y_train, y_test = train_test_split(phone_seqs, langs, test_size=0.2, random_state=42)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, batch_size=500, epochs=100, validation_split=0.2)

# Assuming you have preprocessed data in X_test and y_test

# Evaluate the model on test data
loss, accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2139156/31007606.py in <module>
#      16
#      17 # Train the model
# ---> 18 model.fit(X_train, y_train, batch_size=500, epochs=100, validation_split=0.2)
#      19
#      20 # Assuming you have preprocessed data in X_test and y_test
#
# ~/.conda/envs/asrEnv/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~/.conda/envs/asrEnv/lib/python3.7/site-packages/keras/engine/data_adapter.py in train_validation_split(arrays, validation_split)
#    1664         raise ValueError(
#    1665             "`validation_split` is only supported for Tensors or NumPy "
# -> 1666             "arrays, found following types in the input: {}".format(unsplitable)
#    1667         )
#    1668
#
# ValueError: `validation_split` is only supported for Tensors or NumPy arrays, found following types in the input: [<class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>, <class 'str'>,  ...

# %%
print(len(padded_sequences[0]))
# Out:
# 363
